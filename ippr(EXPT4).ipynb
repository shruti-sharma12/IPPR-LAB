# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti-sharma12/IPPR-LAB/blob/main/ippr(EXPT4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: SHRUTI SHARMA
#
# PRN:1032211936
#
# EXPERIMENT 4

# %% [markdown]
# PART A

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files

img = cv2.imread('eagle.jfif', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)


# 2. Sobel X
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)
cv2_imshow(sobelx)

# 3. Sobel Y
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)
cv2_imshow(sobely)


# 4. Combined Edges (Magnitude Approach)
magnitude = cv2.magnitude(sobelx, sobely)
cv2_imshow(magnitude)

# 5. Laplacian
laplacian = cv2.Laplacian(img, cv2.CV_64F)
cv2_imshow(laplacian)
# Out:
# <PIL.Image.Image image mode=L size=224x149>
# <PIL.Image.Image image mode=L size=224x149>
# <PIL.Image.Image image mode=L size=224x149>
# <PIL.Image.Image image mode=L size=224x149>
# <PIL.Image.Image image mode=L size=224x149>

# %% [markdown]
# PART B
#
# (CANNY EDGE DETECTION)

# %%
import cv2

img = cv2.imread("eagle.jfif")  # Read image

# Applying the Canny Edge filter
edge = cv2.Canny(img, 100, 200)

cv2_imshow(img)
cv2_imshow(edge)
# Out:
# <PIL.Image.Image image mode=RGB size=224x149>
# <PIL.Image.Image image mode=L size=224x149>

# %%
edge1 = cv2.Canny(img, 100, 200,apertureSize=5)
cv2_imshow(edge1)
# Out:
# <PIL.Image.Image image mode=L size=224x149>

# %%
edge2 = cv2.Canny(img, 100, 200,apertureSize=7)
cv2_imshow(edge2)
# Out:
# <PIL.Image.Image image mode=L size=224x149>

# %% [markdown]
# Edge and Harris corner detection
#
# ( It is used to extract corners and infer feature of the image )
#
# (Harris' corner detector takes the differential of the corner score into account with reference to direction directly, instead of using shifting patches for every 45 degree angles, and has been proved to be more accurate in distinguishing between edges and corners.)

# %%
import cv2
import numpy as np

image = cv2.imread('eagle.jfif')

# convert the input image into
# grayscale color space
operatedImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# modify the data type
# setting to 32-bit floating point
operatedImage = np.float32(operatedImage)

# apply the cv2.cornerHarris method
# to detect the corners with appropriate
# values as input parameters
dest = cv2.cornerHarris(operatedImage, 2, 5, 0.07)
#values when changed changes the number of the edges in the image detection.
#blockSize – Neighborhood size (larger value=more sensitivity=larger corners ; small value=sharper corners)
#ksize – Aperture parameter for the Sobel() operator (large value=smoother gradients)
#freeParameter – Harris detector free parameter (influences sentivity of the corner)


# Results are marked through the dilated corners
dest = cv2.dilate(dest, None)

# Reverting back to the original image,
# with optimal threshold value
image[dest > 0.01 * dest.max()]=[0, 0, 255]

# the window showing output image with corners
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x149>

# %% [markdown]
# POST LAB QUESTIONS:
#
# 1. Apply the Sobel edge detector and Laplacian edge detector on the
# highlighted area and comment on the result.
#
# 12 12 12 12 12
# 12 12 12 12 12
# 12 12 12 12 12
# 201 201 201 201 201
# 201 201 201 201 201
#
# To apply the Sobel and Laplacian edge detectors to the highlighted area of the given image, we first need to understand that edge detection algorithms typically operate on grayscale images. Since the given image is represented in grayscale already (all pixels have the intensity value of 201), we can directly apply the edge detection algorithms.
#
# Let's denote the highlighted area as the region where the intensity value is 201. Here's the representation of the area:
#
# ```
# 12 12 12 12 12
# 12 12 12 12 12
# 12 12 12 12 12
# 201 201 201 201 201
# 201 201 201 201 201
# ```
#
# Now, let's apply the Sobel and Laplacian edge detectors to this region:
#
# 1. Sobel Edge Detector:
#    The Sobel operator is used for edge detection by computing the gradient magnitude of the image. It consists of two 3x3 convolution kernels, one for horizontal changes and the other for vertical changes.
#
# 2. Laplacian Edge Detector:
#    The Laplacian operator computes the second derivative of the image. It highlights regions with rapid intensity changes, which typically occur at edges.
#
# Since both detectors aim to highlight edges, we would expect both to produce similar results in this case, given that the highlighted area has a sharp transition from the intensity value of 12 to 201.
#
# After applying these operators, the result would likely show a strong response along the border between the intensity value 12 and 201. This indicates the presence of an edge in the highlighted area. However, since the entire area is uniform with the same intensity value, the detected edges might not be as distinct as they would be in a more varied region.
#
# In summary, applying Sobel and Laplacian edge detectors to the highlighted area would likely detect an edge along the boundary between the intensity value of 12 and 201, but the result might not be as visually striking due to the uniform nature of the highlighted region.
